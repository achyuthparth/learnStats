# %%
import importlib

# List of required packages
required_packages = [
    "torch", "torchvision", "torchaudio",
    "transformers", "datasets", "accelerate",
    "langchain", "langchain_huggingface", "langgraph",
    "nltk", "spacy", "jupyterlab", "huggingface_hub",
    "sentencepiece", "bitsandbytes", "protobuf",
    "tiktoken", "openai"
]

# Check installation status
missing_packages = []
for package in required_packages:
    try:
        importlib.import_module(package)
    except ImportError:
        missing_packages.append(package)

# Display results
if missing_packages:
    print("❌ Missing packages:")
    for pkg in missing_packages:
        print(f"- {pkg}")
    print("\nYou can install them using:\n")
    print(f"pip install {' '.join(missing_packages)}")
else:
    print("✅ All required packages are installed!")
# Out:
# ❌ Missing packages:
# - sentencepiece
# - protobuf
#
# You can install them using:
#
# pip install sentencepiece protobuf

# %% [markdown]
# Setencepiece is having its own issues, protobuf was installed succesfully but the code above is not running correctly
